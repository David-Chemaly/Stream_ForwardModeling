# %%
import numpy as np
import matplotlib.pyplot as plt 

from galpy.df import streamdf
from galpy.orbit import Orbit
from galpy.potential import Potential, TwoPowerTriaxialPotential, LogarithmicHaloPotential
from galpy.actionAngle import actionAngleIsochroneApprox
from galpy.util import conversion #for unit conversions

from astropy import units as u
from astropy.constants import G
G = G.to(u.kpc*u.km**2/u.Msun/u.s**2)

# %%
SEED = 42
np.random.seed(SEED)

# %%
logM = 12
Rs   = 10
q1, q2, q3   = 0.5, 1., 1.5
x0, y0, z0 = -60, 0, 0
vx0, vy0, vz0 = 0, 125, 0
time = 3

logm = 8

# %%
a = Rs*q1
b = q2/q1
c = q3/q1

# %%
pot_halo = TwoPowerTriaxialPotential(amp=(10**logM)*u.Msun, a=a*u.kpc, b=b, c=c, zvec=None, pa=None)

aAI = actionAngleIsochroneApprox(pot=pot_halo, b=0.8)#a*u.kpc)

# %%
obs= Orbit([x0, y0, z0,
            vx0, vy0, vz0])

# %%
0.365/220
# Out:
# 0.001659090909090909

# %%
sdf= streamdf(0.365/220,
              progenitor=obs,
              pot=pot_halo,
              aA=aAI,
              leading=True,
              nTrackChunks=11,
              tdisrupt=time*u.Gyr)
# Out:
# galpyWarning: Cannot use C integration because some of the potentials are not implemented in C (using odeint instead)
# /Users/davidchemaly/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngleIsochrone.py:253: RuntimeWarning: invalid value encountered in sqrt
#   Jr = self.amp / numpy.sqrt(-2.0 * E) - 0.5 * (
#
# /Users/davidchemaly/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngleIsochrone.py:257: RuntimeWarning: invalid value encountered in power
#   Omegar = (-2.0 * E) ** 1.5 / self.amp
#
# /Users/davidchemaly/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngleIsochrone.py:282: RuntimeWarning: invalid value encountered in sqrt
#   numpy.sqrt((1.0 + e) / (1.0 - e)) * numpy.tan(0.5 * eta)
#
# /Users/davidchemaly/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngleIsochrone.py:285: RuntimeWarning: invalid value encountered in sqrt
#   numpy.sqrt((1.0 + e + 2.0 * self.b / c) / (1.0 - e + 2.0 * self.b / c))
#
# /Users/davidchemaly/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngleIsochrone.py:296: RuntimeWarning: divide by zero encountered in divide
#   tani = numpy.sqrt(L**2.0 - Lz**2.0) / Lz
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sdf= streamdf(0.365/220,
#       2               progenitor=obs,
#       3               pot=pot_halo,
#       4               aA=aAI,
#       5               leading=True,
#       6               nTrackChunks=11,
#       7               tdisrupt=time*u.Gyr)
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/df/streamdf.py:207, in streamdf.__init__(self, sigv, progenitor, pot, aA, useTM, tdisrupt, sigMeanOffset, leading, sigangle, deltaAngleTrack, nTrackChunks, nTrackIterations, progIsTrack, ro, vo, Vnorm, Rnorm, R0, Zsun, vsun, multi, interpTrack, useInterp, nosetup, nospreadsetup, approxConstTrackFreq, useTMHessian, custom_transform)
#     205 else:
#     206     self._multi = multi
# --> 207 self._progenitor_setup(progenitor, leading, useTMHessian)
#     208 sigangle = conversion.parse_angle(sigangle)
#     209 deltaAngleTrack = conversion.parse_angle(deltaAngleTrack)
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/df/streamdf.py:274, in streamdf._progenitor_setup(self, progenitor, leading, useTMHessian)
#     266     self._progenitor_Omega = numpy.array(
#     267         [
#     268             self._progenitor_Omegar,
#    (...)
#     271         ]
#     272     ).reshape(3)
#     273 else:
# --> 274     self._dOdJp = calcaAJac(
#     275         self._progenitor.vxvv[0], self._aA, dxv=None, dOdJ=True, _initacfs=acfs
#     276     )
#     277 self._dOdJpInv = numpy.linalg.inv(self._dOdJp)
#     278 self._dOdJpEig = numpy.linalg.eig(self._dOdJp)
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/df/streamdf.py:3948, in calcaAJac(xv, aA, dxv, freqs, dOdJ, actionsFreqsAngles, lb, coordFunc, vo, ro, R0, Zsun, vsun, _initacfs)
#    3946 else:
#    3947     tR, tvR, tvT, tz, tvz, tphi = xv[0], xv[1], xv[2], xv[3], xv[4], xv[5]
# -> 3948 tjr, tlz, tjz, tOr, tOphi, tOz, tar, taphi, taz = aA.actionsFreqsAngles(
#    3949     tR, tvR, tvT, tz, tvz, tphi
#    3950 )
#    3951 xv[ii] -= dxv[ii]
#    3952 angleIndx = 3
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/util/conversion.py:1249, in actionAngle_physical_input.<locals>.wrapper(*args, **kwargs)
#    1247         newargs = newargs + (args[ii],)
#    1248 args = newargs
# -> 1249 return method(*args, **kwargs)
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/util/conversion.py:1204, in physical_conversion_actionAngle.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#    1202     return newOut
#    1203 else:
# -> 1204     return method(*args, **kwargs)
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngle.py:269, in actionAngle.actionsFreqsAngles(self, *args, **kwargs)
#     245 """
#     246 Evaluate the actions, frequencies, and angles (jr,lz,jz,Omegar,Omegaphi,Omegaz,angler,anglephi,anglez)
#     247
#    (...)
#     266 - 2014-01-03 - Written for top level - Bovy (IAS)
#     267 """
#     268 try:
# --> 269     return self._actionsFreqsAngles(*args, **kwargs)
#     270 except AttributeError:  # pragma: no cover
#     271     raise NotImplementedError(
#     272         "'actionsFreqsAngles' method not implemented for this actionAngle module"
#     273     )
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngleIsochroneApprox.py:285, in actionAngleIsochroneApprox._actionsFreqsAngles(self, *args, **kwargs)
#     283     ts = conversion.parse_time(ts, ro=self._ro, vo=self._vo)
#     284 else:
# --> 285     ts = numpy.empty(R.shape[1])
#     286     ts[self._ntintJ - 1 :] = self._tsJ
#     287     ts[: self._ntintJ - 1] = -self._tsJ[1:][::-1]
#
# IndexError: tuple index out of range

# %%
# lp = LogarithmicHaloPotential(normalize=1.,q=0.9)
lp = TwoPowerTriaxialPotential(amp=(10**logM)*u.Msun, a=a*u.kpc, b=b, c=c, zvec=None, pa=None)
aAI = actionAngleIsochroneApprox(pot=pot_halo, b=0.8)#a*u.kpc)
aAI= actionAngleIsochroneApprox(pot=lp,b=0.8)

obs= Orbit([1.56148083,0.35081535,-1.15481504,0.88719443,-0.47713334,0.12019596])

sigv = 10 #km/s
time = 2 # Gyr
sdf= streamdf(sigv/220.,progenitor=obs,pot=lp,aA=aAI, leading=True, nTrackChunks=11,tdisrupt=time/conversion.time_in_Gyr(220.,8.))

sdf.plotCompareTrackAAModel()
# Out:
# galpyWarning: Cannot use C integration because some of the potentials are not implemented in C (using odeint instead)
# /Users/davidchemaly/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngleIsochrone.py:253: RuntimeWarning: invalid value encountered in sqrt
#   Jr = self.amp / numpy.sqrt(-2.0 * E) - 0.5 * (
#
# /Users/davidchemaly/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngleIsochrone.py:257: RuntimeWarning: invalid value encountered in power
#   Omegar = (-2.0 * E) ** 1.5 / self.amp
#
# /Users/davidchemaly/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngleIsochrone.py:282: RuntimeWarning: invalid value encountered in sqrt
#   numpy.sqrt((1.0 + e) / (1.0 - e)) * numpy.tan(0.5 * eta)
#
# /Users/davidchemaly/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/actionAngle/actionAngleIsochrone.py:285: RuntimeWarning: invalid value encountered in sqrt
#   numpy.sqrt((1.0 + e + 2.0 * self.b / c) / (1.0 - e + 2.0 * self.b / c))
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[41], line 10
#       8 sigv = 10 #km/s
#       9 time = 2 # Gyr
# ---> 10 sdf= streamdf(sigv/220.,progenitor=obs,pot=lp,aA=aAI, leading=True, nTrackChunks=11,tdisrupt=time/conversion.time_in_Gyr(220.,8.))
#      12 sdf.plotCompareTrackAAModel()
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/df/streamdf.py:207, in streamdf.__init__(self, sigv, progenitor, pot, aA, useTM, tdisrupt, sigMeanOffset, leading, sigangle, deltaAngleTrack, nTrackChunks, nTrackIterations, progIsTrack, ro, vo, Vnorm, Rnorm, R0, Zsun, vsun, multi, interpTrack, useInterp, nosetup, nospreadsetup, approxConstTrackFreq, useTMHessian, custom_transform)
#     205 else:
#     206     self._multi = multi
# --> 207 self._progenitor_setup(progenitor, leading, useTMHessian)
#     208 sigangle = conversion.parse_angle(sigangle)
#     209 deltaAngleTrack = conversion.parse_angle(deltaAngleTrack)
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/galpy/df/streamdf.py:278, in streamdf._progenitor_setup(self, progenitor, leading, useTMHessian)
#     274     self._dOdJp = calcaAJac(
#     275         self._progenitor.vxvv[0], self._aA, dxv=None, dOdJ=True, _initacfs=acfs
#     276     )
#     277 self._dOdJpInv = numpy.linalg.inv(self._dOdJp)
# --> 278 self._dOdJpEig = numpy.linalg.eig(self._dOdJp)
#     279 return None
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/numpy/linalg/linalg.py:1329, in eig(a)
#    1327 _assert_stacked_2d(a)
#    1328 _assert_stacked_square(a)
# -> 1329 _assert_finite(a)
#    1330 t, result_t = _commonType(a)
#    1332 extobj = get_linalg_error_extobj(
#    1333     _raise_linalgerror_eigenvalues_nonconvergence)
#
# File ~/miniforge3/envs/Astro/lib/python3.10/site-packages/numpy/linalg/linalg.py:218, in _assert_finite(*arrays)
#     216 for a in arrays:
#     217     if not isfinite(a).all():
# --> 218         raise LinAlgError("Array must not contain infs or NaNs")
#
# LinAlgError: Array must not contain infs or NaNs

# %%
lb = sdf.sample(n=1000,xy=True)
plt.scatter(lb[0],lb[1])

# %%
lb = sdf.sample(n=1000,xy=True)
plt.scatter(lb[0],lb[1])
